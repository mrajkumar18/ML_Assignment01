# %% [markdown]
# ---
# ---
#
# <center><h1>📍 📍 Assignment: Subsetting and Modifying Data📍 📍</h1></center>
#
#
# ---
#
#
# #### `READ THE BIG MART SALES DATA`
#
#
# ---

# %%
import pandas as pd

# %%
data = pd.read_csv('datasets/big_mart_sales.csv')

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# ---
#
# #### `Select the rows where Item_MRP is less than 100`
#
#
# ---

# %%
# WRITE YOUR CODE HERE - QUESTION 1
# Rows where Item_MRP is less than 100
data[data.Item_MRP < 100]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1              DRC01        5.920          Regular         0.019278
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 8              FDH17       16.200          Regular         0.016687
# ...              ...          ...              ...              ...
# 8513           FDH31       12.000          Regular         0.020407
# 8514           FDA01       15.000          Regular         0.054489
# 8516           NCJ19       18.600          Low Fat         0.118661
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 1            Soft Drinks   48.2692            OUT018
# ...

# %% [markdown]
# ---
#
# #### `Select the rows where Outlet_Location_Type is Tier 1 and Outlet_Establishment_Year is from the list [1987, 1988, 2009]`
#
# ---

# %%
select_columns = ['Outlet_Location_Type','Outlet_Establishment_Year','Item_MRP']
data[(data.Outlet_Location_Type == 'Tier 1')][select_columns]
# Out:
#      Outlet_Location_Type  Outlet_Establishment_Year  Item_MRP
# 0                  Tier 1                       1999  249.8092
# 2                  Tier 1                       1999  141.6180
# 10                 Tier 1                       1999   45.5402
# 11                 Tier 1                       1997  144.1102
# 12                 Tier 1                       1999  145.4786
# ...                   ...                        ...       ...
# 8480               Tier 1                       1985  154.5340
# 8490               Tier 1                       1985  162.3552
# 8492               Tier 1                       1997  104.4964
# 8517               Tier 1                       1997  178.8318
# 8522               Tier 1                       1997   75.4670
#
# [2388 rows x 3 columns]

# %%
data[(data.Outlet_Location_Type == 'Tier 1') & (data.Outlet_Establishment_Year == 1997)]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 11             FDA03       18.500          Regular         0.045464
# 13             FDS46       17.600          Regular         0.047257
# 15             FDP49        9.000          Regular         0.069089
# 24             FDR28       13.850          Regular         0.025896
# 34             DRH01       17.500          Low Fat         0.097904
# ...              ...          ...              ...              ...
# 8450           FDC28        7.905          Low Fat         0.054987
# 8461           FDB17       13.150          Low Fat         0.036672
# 8492           FDT34        9.300          Low Fat         0.174350
# 8517           FDF53       20.750              reg         0.083607
# 8522           DRG01       14.800          Low Fat         0.044878
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 11           Dairy  144.1102            OUT046                       1997
# ...

# %%
select_columns = ['Outlet_Location_Type','Item_MRP','Outlet_Size']
data[(data.Outlet_Establishment_Year.isin([1987,1988,2009]))][select_columns]
# Out:
#      Outlet_Location_Type  Item_MRP Outlet_Size
# 1                  Tier 3   48.2692      Medium
# 4                  Tier 3   53.8614        High
# 5                  Tier 3   51.4008      Medium
# 6                  Tier 3   57.6588        High
# 14                 Tier 3  196.4426        High
# ...                   ...       ...         ...
# 8512               Tier 3  178.3028        High
# 8515               Tier 3  157.5288      Medium
# 8516               Tier 3   58.7588      Medium
# 8518               Tier 3  214.5218        High
# 8521               Tier 3  103.1332      Medium
#
# [1860 rows x 3 columns]

# %%
# WRITE YOUR CODE HERE - QUESTION 2
# Select the rows where Outlet_Location_Type is Tier 1 and Outlet_Establishment_Year is from the list [1987, 1988, 2009]

data[(data.Outlet_Location_Type == 'Tier 1') & (data.Outlet_Establishment_Year.isin([1987,1988,2009]))]
# Out:
# Empty DataFrame
# Columns: [Item_Identifier, Item_Weight, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type, Outlet_Type, Item_Outlet_Sales]
# Index: []

# %% [markdown]
# ---
#
# #### `Update the values of the column Outlet_Type using the mapping given below`
#
#
# ---

# %%
mapping = {
    'Supermarket Type1' : 1,
    'Supermarket Type2' : 2,
    'Grocery Store'     : 3,
    'Supermarket Type3' : 4
}

# %%
data.Outlet_Type.unique()
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
#        'Supermarket Type3'], dtype=object)

# %%
# WRITE YOUR CODE HERE - QUESTION 3
# Update the values of the column Outlet_Type using the mapping given below
data.Outlet_Type.map(mapping)

# using map function to update the values in Outlet_Type
data.Outlet_Type = data.Outlet_Type.map(mapping)

# %%
data.Outlet_Type.unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %% [markdown]
# ---
#
# #### `Fill the missing values in the column 'Outlet_Size' by Medium using loc`
#
# ---

# %%
data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data.Outlet_Size.value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
data.Outlet_Size.dtypes
# Out:
# dtype('O')

# %%
# WRITE YOUR CODE HERE - QUESTION 4
# Fill the missing values in the column 'Outlet_Size' by Medium using loc

data.loc[(data.Outlet_Size.isna() == True) , 'Outlet_Size'] = 'Medium'

# %%
data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data.Item_Weight
# Out:
# 0        9.300
# 1        5.920
# 2       17.500
# 3       19.200
# 4        8.930
#          ...
# 8518     6.865
# 8519     8.380
# 8520    10.600
# 8521     7.210
# 8522    14.800
# Name: Item_Weight, Length: 8523, dtype: float64

# %%
data.Item_Weight.mean()
# Out:
# 12.857645184135976

# %%
# Missing vlaue in Item_Weight replaced with Item_Weight
data.loc[(data.Item_Weight.isna() == True) , 'Item_Weight'] = (data.Item_Weight.mean())

# %%
# Final no missing value
data.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64
